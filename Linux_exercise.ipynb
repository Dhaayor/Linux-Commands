# %%
#Create a directory structure

# !mkdir /content/New_directory/

# %%
#Create some sample files

# !touch /content/New_directory/Sample.txt

# %%
#Create some sample files -2

# !touch /content/New_directory/sample.csv

# %%
#Create some sample files - 3

with open('/content/New_directory/test.txt', 'w') as f:
  f.write('hello world ! my name is Oladayo Abiodun and i am pursuing an advanced diploma in Big data analytics')

# %%
# List the contents of the linux_exercise directory

# !ls /content/New_directory/
# Out:
# sample.csv  Sample.txt	test.txt

# %%
#Use the find command to locate all .txt files

# !find
# Out:
# .
# ./.config
# ./.config/config_sentinel
# ./.config/hidden_gcloud_config_universe_descriptor_data_cache_configs.db
# ./.config/.last_update_check.json
# ./.config/active_config
# ./.config/configurations
# ./.config/configurations/config_default
# ./.config/gce
# ./.config/.last_survey_prompt.yaml
# ./.config/default_configs.db
# ./.config/.last_opt_in_prompt.yaml
# ./.config/logs
# ./.config/logs/2024.09.17
# ./.config/logs/2024.09.17/13.20.59.563047.log
# ./.config/logs/2024.09.17/13.21.35.926343.log
# ./.config/logs/2024.09.17/13.21.48.855748.log
# ./.config/logs/2024.09.17/13.21.21.769858.log
# ./.config/logs/2024.09.17/13.21.49.596863.log
# ./.config/logs/2024.09.17/13.21.34.718011.log
# ./New_directory
# ./New_directory/sample.csv
# ./New_directory/test.txt
# ./New_directory/Sample.txt
# ./sample_data
# ./sample_data/README.md
# ./sample_data/anscombe.json
# ./sample_data/mnist_test.csv
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ...

# %%
#Count the number of lines in all text files

# !wc ./New_directory/Sample.txt
# Out:
# 0 0 0 ./New_directory/Sample.txt

# %%
#Search for the word "Hello" in all files - using one as a case study

# !grep "Hello" ./New_directory/test.txt

# %%
# !grep "Hello" ./sample_data/anscombe.json

# %%
# !grep "Hello" ./sample_data/README.md

# %%
#Move file2.txt to folder2

# !mv ./sample_data/anscombe.json ./New_directory/

# %%
# Create a symbolic link to file1.txt in folder2

# !ln -s ./sample_data/mnist_test.csv ./New_directory/

# %%
#Use find to locate files modified in the last minute

# !find ./New_directory/ -type f -mmin -1

# %%
# Finally, clean up by removing the linux_exercise directory
# !mkdir ./linux_exercise

# %%
# !rmdir ./linux_exercise/
